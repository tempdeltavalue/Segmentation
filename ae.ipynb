# %% [markdown]
# <a href="https://colab.research.google.com/github/temptitle/Segmentation/blob/main/ae.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/temptitle/Segmentation
# Out:
# Cloning into 'Segmentation'...
# remote: Enumerating objects: 398, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 398 (delta 1), reused 7 (delta 0), pack-reused 386
# Receiving objects: 100% (398/398), 216.85 MiB | 29.84 MiB/s, done.
# Resolving deltas: 100% (122/122), done.
# Checking out files: 100% (141/141), done.

# %%
# !wget https://www.dropbox.com/s/mbidgszwfgwr7a4/instances_train2017.json

# !wget https://www.dropbox.com/s/y6gws9cockrulov/COCOhumanTrainSubset.zip

import zipfile
with zipfile.ZipFile("COCOhumanTrainSubset.zip","r") as zip_ref:
    zip_ref.extractall("COCOhumanTrainSubset")

# !rm "COCOhumanTrainSubset.zip"
# Out:
# --2021-04-19 15:38:12--  https://www.dropbox.com/s/mbidgszwfgwr7a4/instances_train2017.json
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/mbidgszwfgwr7a4/instances_train2017.json [following]
# --2021-04-19 15:38:13--  https://www.dropbox.com/s/raw/mbidgszwfgwr7a4/instances_train2017.json
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc1b67cb45b3d39bed75bb5c5169.dl.dropboxusercontent.com/cd/0/inline/BM7UVLKmJ7geFIXMH_RGOS1hordF5whfXpDK_PVg_DsZBJ1p8z1ilRLqXdLFvZMzjeG9QxYwBOL86XfRIu0MlvBoNncP7BTas441bvHIeOvTaE5h3WMWWgjFmz1CNILyJKXJcDHOjjIghDHY7qQ1R7-F/file# [following]
# ...

# %%
# %cd /content/Segmentation
# Out:
# /content/Segmentation

# %%
# !python pytorch-AE/train.py
# Out:
# AE
# Train Epoch: 1 [0/1000 (0%)]	Loss: 392375.000000
# Train Epoch: 1 [80/1000 (8%)]	Loss: 326637.500000
# Train Epoch: 1 [160/1000 (16%)]	Loss: 368537.500000
# Train Epoch: 1 [240/1000 (24%)]	Loss: 348462.500000
# Train Epoch: 1 [320/1000 (32%)]	Loss: 344237.500000
# Train Epoch: 1 [400/1000 (40%)]	Loss: 375362.500000
# Train Epoch: 1 [480/1000 (48%)]	Loss: 357237.500000
# Train Epoch: 1 [560/1000 (56%)]	Loss: 388612.500000
# Train Epoch: 1 [640/1000 (64%)]	Loss: 369612.500000
# Train Epoch: 1 [720/1000 (72%)]	Loss: 350200.000000
# Train Epoch: 1 [800/1000 (80%)]	Loss: 379800.000000
# Train Epoch: 1 [880/1000 (88%)]	Loss: 385487.500000
# Train Epoch: 1 [960/1000 (96%)]	Loss: 384512.500000
# ====> Epoch: 1 Average loss: 374349.3000
# Train Epoch: 2 [0/1000 (0%)]	Loss: 375187.500000
# Train Epoch: 2 [80/1000 (8%)]	Loss: 347425.000000
# Train Epoch: 2 [160/1000 (16%)]	Loss: 376087.500000
# Train Epoch: 2 [240/1000 (24%)]	Loss: 354537.500000
# ...

# %%
# !python AEPytorch/UNET/train.py
# Out:
# INFO: Using device cpu
# INFO: Network:
# 	3 input channels
# 	1 output channels (classes)
# 	Bilinear upscaling
# train <torch.utils.data.dataset.Subset object at 0x7fe61d520350>
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# INFO: Starting training:
#         Epochs:          55
#         Batch size:      1
#         Learning rate:   0.0001
#         Training size:   900
#         Validation size: 100
#         Checkpoints:     True
#         Device:          cpu
#         Images scaling:  1
#
# Epoch 1/55:   0% 0/900 [00:00<?, ?img/s]
